# %% [markdown]
# # Description
#
# Objective of this insurance dataset is to <b> predict charges </b>. Datasets consists of Several Predictor (Independent)Variables and target variables
# (charges)
#
#
# <b> Dataset url</b>: https://www.kaggle.com/datasets/awaiskaggler/insurance-csv
#
#
#
# # Name of Columns with their meanings:
#
# 1) age : age of primary beneficiary
#
# 2) sex : insurance contractor gender,female,male
#
# 3) bmi : Body mass index providing an understanding of body ,weights that are relative high or low relative to hight objective index of body weight (Kg/m2) using ratio of height to weight ideally 18.5 to 24.9
#
# 4) children : Number of children  covered by heallth insurance /Number of independents
#
# 5) smoker : Smoking
#
# 6) region : beneficiary residential area  in US ,northeast,southeast,southwest,northwest
#
# 7) charges : Individiual medical costs  billed by health insurance

# %% [markdown]
# # Step 1: Importing an Libraries Like: Numpy, Pandas,Matplotlib,Seaborn

# %%
# Numpy

import numpy as np


# Pandas 

import pandas as pd


# Matplotlib

import matplotlib.pyplot as plt 


# Seaborn 

import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2: Load an dataset

# %%
# load an dataset using pd.read_csv()


df = pd.read_csv('insurance.csv')

# %% [markdown]
# # Step 3: Exploratory Data Analysis
#
# Exploratory Data-Analysis (EDA) also known as Data Exploration is a step in Data Analysis Process where number of techniques are used to better Understand an dataset being used
#
#
# In this Step we will perform below operations
#
# # 3.1 Understanding your Variables:
#             3.1.1) Head of Dataset
#             3.1.2) Shape of Dataset
#             3.1.3) List types of all columns
#             3.1.4)Info of dataset
#             3.1.5)Summary of Dataset
#
#
# # 3.2 Data Cleaning:
#
#                 3.2.1) Check Duplicates
#                 3.2.2) Check NULL Values
#
#
#
#
# ### 3.1.1 Head of Dataset:
# head() function will tell you top records  in data set By Default ,python shows you only top 5 records
#
#
# head(n) function will return  first n rows  for object based on position . It is usefull  for quickly testing if your object has right type of data in it By default it will shows 5 rows

# %%
# Display first five records of data:

df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>female</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>yes</td>
#       <td>southwest</td>
#       <td>16884.92</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>male</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>no</td>
#       <td>southeast</td>
#       <td>1725.55</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
# Display last five Records in Data 

df.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1333</th>
#       <td>50</td>
#       <td>male</td>
#       <td>31.0</td>
#       <td>3</td>
#       <td>no</td>
#       <td>northwest</td>
#       <td>10600.55</td>
#     </tr>
#     <tr>
#       <th>1334</th>
#       <td>18</td>
#       <td>female</td>
#       <td>31.9</td>
#       <td>0</td>
#       <td>no</td>
#       <td>northeast</td>
#       <td>2205.98</td>
#     </tr>
#     <tr>
# ...

# %%
# Display any number of records randomly

df.sample(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1268</th>
#       <td>20</td>
#       <td>female</td>
#       <td>33.3</td>
#       <td>0</td>
#       <td>no</td>
#       <td>southwest</td>
#       <td>1880.49</td>
#     </tr>
#     <tr>
#       <th>1172</th>
#       <td>56</td>
#       <td>female</td>
#       <td>41.9</td>
#       <td>0</td>
#       <td>no</td>
#       <td>southeast</td>
#       <td>11093.62</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # 3.1.2) Shape of Dataset
#
#
# shape function gives us numbers of rows and columns of dataset.

# %%
# number of rows and columns 

df.shape
# Out:
# Out[208]: (1338, 7)

# %% [markdown]
# No of rows  = 1338
#
# No of columns = 7

# %% [markdown]
# # 3.1.3) List types of all columns
#
# Using df.dtypes we get list of all types of all columns in our dataset

# %%
df.dtypes
# Out:
# Out[209]: age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# # 3.1.4)Info of dataset
#
#
# info() is used to check  information about data  and datatypes of each respective attribute

# %%
# finding out if dataset contains an null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # 3.1.5)Summary of Dataset
#
#
# describe Method  will help to see how data  has been spread for numerical values . We can clearly see minimum value,mean value,different percentile values and maximum values

# %%
# statistically Summary

df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>39.207025</td>
#       <td>30.665471</td>
#       <td>1.094918</td>
#       <td>13270.422414</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>14.049960</td>
#       <td>6.098382</td>
#       <td>1.205493</td>
#       <td>12110.011240</td>
#     </tr>
#     <tr>
#       <th>min</th>
# ...

# %% [markdown]
# ## Numerical Features

# %%
[features for features in df.dtypes[df.dtypes !='object'].index]
# Out:
# Out[212]: ['age', 'bmi', 'children', 'charges']

# %%
num_features = df.dtypes[df.dtypes !=object].index

# %%
num_features
# Out:
# Out[214]: Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %%
len(num_features)
# Out:
# Out[215]: 4

# %%
# summarize numerical features

df[num_features].describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#       <td>1338.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>39.207025</td>
#       <td>30.665471</td>
#       <td>1.094918</td>
#       <td>13270.422414</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>14.049960</td>
#       <td>6.098382</td>
#       <td>1.205493</td>
#       <td>12110.011240</td>
#     </tr>
#     <tr>
#       <th>min</th>
# ...

# %% [markdown]
# ## Distributon of Categorical Features

# %%
cat_features = df.dtypes[df.dtypes=='object'].index
cat_features
# Out:
# Out[217]: Index(['sex', 'smoker', 'region'], dtype='object')

# %%
len(cat_features)
# Out:
# Out[218]: 3

# %%
df[cat_features].describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1338</td>
#       <td>1338</td>
#       <td>1338</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>2</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>male</td>
#       <td>no</td>
#       <td>southeast</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>676</td>
#       <td>1064</td>
#       <td>364</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Check unique labels in Categorical  variables

# %%
# check unique labels for sex variable 
df['sex'].unique()
# Out:
# Out[220]: array(['female', 'male'], dtype=object)

# %%
#print number of labels in sex variable 
print(df.sex.value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
# check unique labels for smoker variable 
df['smoker'].unique()
# Out:
# Out[222]: array(['yes', 'no'], dtype=object)

# %%
#print number of labels in 'smoker'  variable 
print(df.smoker.value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['region'].unique()
# Out:
# Out[225]: array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
#print number of labels in 'region'  variable 
print(df.region.value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# # 3.2 Data Cleaning:
#
# ## 3.2.1) Drop  Duplicates
#
# check if there is any duplicate rows exist or not, if exists  then we should remove from  the dataframe

# %%
# check shape before drop duplicates 
df.shape
# Out:
# Out[227]: (1338, 7)

# %%
df = df.drop_duplicates()

# %%
# check shape after dropping duplicates

df.shape
# Out:
# Out[229]: (1337, 7)

# %% [markdown]
# Before drop and after drop  duplicates  the dataset has same  shape which means no duplicates in dataset
#
# But here Before dropping number of rows = 1338
# After drop duplicates  Number of rows = 1337
#
# which means only one Duplicate  exist now  which is removed
#
# Finally our dataset  shape is (1337,7)

# %% [markdown]
# # 3.2.2 Check NULL Values
# Using .isnull().sum()  function we can see  null values in every column in dataset

# %%
# count of null values 
# check missing values in any column
# Display null values in every column in dataset
df.isnull().sum()
# Out:
# Out[230]: age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# There is no null values in a given dataset

# %% [markdown]
# # 4 Data Visualizations:
#
# 4.2)
# Histograms are most of common graphs used to diplay numeric data
#
# distribution of data - whether data is normally distributed  or if its skewed (to left or right)

# %%
# Histogram of each feature 

df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# # Scatter plot
#
# Scatterplot is a type of graph which plots values of two variables along two axes  like age and height  Scatterplots usefull for many reasons
# like corelation , matrices  it allows you to understand  a realtionship n between  two varibles

# %%
# Scatter plot matric 

from pandas.plotting import scatter_matrix

scatter_matrix(df,figsize=(20,20))
# Out:
# Out[232]: array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='bmi', ylabel='age'>,
#         <AxesSubplot:xlabel='children', ylabel='age'>,
#         <AxesSubplot:xlabel='charges', ylabel='age'>],
#        [<AxesSubplot:xlabel='age', ylabel='bmi'>,
#         <AxesSubplot:xlabel='bmi', ylabel='bmi'>,
#         <AxesSubplot:xlabel='children', ylabel='bmi'>,
#         <AxesSubplot:xlabel='charges', ylabel='bmi'>],
#        [<AxesSubplot:xlabel='age', ylabel='children'>,
#         <AxesSubplot:xlabel='bmi', ylabel='children'>,
#         <AxesSubplot:xlabel='children', ylabel='children'>,
#         <AxesSubplot:xlabel='charges', ylabel='children'>],
#        [<AxesSubplot:xlabel='age', ylabel='charges'>,
#         <AxesSubplot:xlabel='bmi', ylabel='charges'>,
#         <AxesSubplot:xlabel='children', ylabel='charges'>,
#         <AxesSubplot:xlabel='charges', ylabel='charges'>]], dtype=object)

# %% [markdown]
# # Feature Engineering:
#
# ### Converting Categorical Variable to Numerical variable
#
# Apply get_dummies() Method:
#
# This is one of approach and also each one to encode  Categorical Data  pandas.get_dummies() method  method  takes categorical  feature as an argument Then it Creates Dummy Variable  for every label in feature, Such that  each dummy varable  holds data as 1 or 0  Indicate presence of particular label  and 0  indicates  the absence of particular level
#
#
#
#
# for Example :  if a feature contains Male and Female  After Applying pandas.get_dummies to that feature  to that feature ,Dummy variable  for both male and  Female labels are created i.e Dummy variables  are created  for every label  in the feature  so that Dummy variabe holds 1 in presence of that label  and as 0  in absence of that label

# %%
dummies = pd.get_dummies(df.sex)

# %%
dummies.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>female</th>
#       <th>male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
merge = pd.concat([df,dummies],axis=1)
merge.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#       <th>female</th>
#       <th>male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>female</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>yes</td>
#       <td>southwest</td>
#       <td>16884.92</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>male</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>no</td>
# ...

# %%
df1 = merge.drop(['sex','female'],axis=1)
df1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#       <th>male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>yes</td>
#       <td>southwest</td>
#       <td>16884.92</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>no</td>
#       <td>southeast</td>
#       <td>1725.55</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
dumi1 = pd.get_dummies(df1.smoker)
dumi1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>no</th>
#       <th>yes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
merge1 = pd.concat([df1,dumi1],axis=1)
df2 = merge1.drop(['smoker','no'],axis=1)
df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>region</th>
#       <th>charges</th>
#       <th>male</th>
#       <th>yes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>southwest</td>
#       <td>16884.92</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>southeast</td>
#       <td>1725.55</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
dummi2=pd.get_dummies(df2.region)
dummi2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>northeast</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...

# %%
merge2 = pd.concat([df2,dummi2],axis=1)
merge2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>region</th>
#       <th>charges</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northeast</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>southwest</td>
#       <td>16884.92</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
# ...

# %%
df3 = merge2.drop(['region','northeast'],axis=1)
df3.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>16884.92</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>1725.55</td>
#       <td>1</td>
#       <td>0</td>
# ...

# %%
df3.shape
# Out:
# Out[244]: (1337, 9)

# %% [markdown]
# # data is ready to train the model
#
# ## 5) Split DataFrame  into X and Y

# %%
target_name = 'charges'

# Seperate objwct for target feature

y = df3[target_name]

# 


# Seperate object Input  feature 
X= df3.drop(target_name,axis=1)

# %%
X.shape
# Out:
# Out[246]: (1337, 8)

# %%
y.head()
# Out:
# Out[247]: 0    16884.92
# 1     1725.55
# 2     4449.46
# 3    21984.47
# 4     3866.86
# Name: charges, dtype: float64

# %% [markdown]
# # 6) Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# Out[250]: ((1069, 8), (1069,))

# %%
X_test.shape,y_test.shape
# Out:
# Out[251]: ((268, 8), (268,))

# %% [markdown]
# # 7 Building Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression
# Creating an Object 
lr = LinearRegression()
    
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %% [markdown]
# # Evaluation Metrics

# %%
# train score

train_score = lr.score(X_train,y_train)
print('Train_score',train_score)
# Out:
# Train_score 0.7529469407973212

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)

print("r_2 Score",score)
# Out:
# r_2 Score 0.7405436314738477

# %%
from sklearn import metrics

print("Mean Absolute  Error",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Square Error",np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
# Out:
# Mean Absolute  Error 4393.838937013875
# Mean Squared Error 41911806.980784714
# Root Mean Square Error 66.286038779021

# %%
df4 = pd.DataFrame({'Actual':y_test,'predicted':y_pred,'variance':y_test-y_pred})
df4.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Actual</th>
#       <th>predicted</th>
#       <th>variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13</th>
#       <td>11090.72</td>
#       <td>14428.920783</td>
#       <td>-3338.200783</td>
#     </tr>
#     <tr>
#       <th>1052</th>
#       <td>9288.03</td>
#       <td>11290.895725</td>
#       <td>-2002.865725</td>
#     </tr>
#     <tr>
#       <th>172</th>
#       <td>1694.80</td>
#       <td>-1768.263286</td>
#       <td>3463.063286</td>
#     </tr>
#     <tr>
#       <th>395</th>
#       <td>7526.71</td>
#       <td>5781.158123</td>
#       <td>1745.551877</td>
#     </tr>
# ...

# %%
# cross check values
df3.head(14)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>16884.92</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>1725.55</td>
#       <td>1</td>
#       <td>0</td>
# ...

# %%
lr.predict([[56,39.8,0,0,0,0,1,0]])
# Out:
# Out[260]: array([14428.92078333])

# %%
print("Intercept",lr.intercept_)
# Out:
# Intercept -11706.11877378776

# %%
print("coeffiecients",lr.coef_)
# Out:
# coeffiecients [  253.79928425   337.98283552   527.21806988   -38.25699752
#  23727.96144273  -875.09160778 -1529.43721458 -1124.21294814]

# %%
# According to linear Regression y = mx+b
# here in this case we have 8 input features 

# Equation will be y = m1x1 +m2x2 + m3x3 +m4x4 +m5x5 +m6x6 +m7x7 +m8 x8 + b
# here b  is intercept
                            
# here m1 =  253.79928425  ,m2= 337.98283552  m3=527.21806988   m4=-38.25699752    m5=23727.96144273 ,m6=-875.09160778  m7=-1529.43721458 ,m8=1124.21294814

#            x1 = 56,       x2 = 39.8,        x3=0,            x4=0,                x5=0,              x6=0,            x7=1,             x8=0


253.79928425*56 + 337.98283552* 39.8 + 527.21806988 * 0  + 38.25699752*0 + 23727.96*0 +-875.09160778*0 + -1529.43721458*1 + 1124.212*0 - 11706.11877378776
# Out:
# Out[263]: 14428.920783328236

# %% [markdown]
# # Feature Selection
#
#
# Few Advantages of Feature Selection
#
# 1) Faster Training time
#
# 2) Decrease in complexity
#
# 3) Improved Accuracy and Performance
#
# 4) most important one - reduction in over-fitting
#
#
#
# # There are many kinds of feature selection methods
#
#             1) Forward Selection
#
#             2) Recursive Faeture Elimination
#
#
#             3) Backward Elimination
#
# Simplest and widely used one is Backward Elimination Method
#
#
# ### Building an opotimal model  using "Backward Elimination Method"
#
# When we are building an Machine Learning Model, it is important that we select only those features  or predictors which are necessary
#
# So we have  50 features or predictors in our dataset That doesnot necessarily mean that  we need to have all 50 features in our model
#
# There are various ways in whuch you find it out  which features have little impact on model  and which one you cam remove from your dataset
#
#
# Similar idea  can be applied  in Backward Elimination  -- whether a feature  significantly impacts the output or not
#
#
# <b> P-value </b> helps determine  whether hypothesis is <b> rejected or accepted </b>

# %% [markdown]
# # Backward Elimination Method Procedure
#
# # Step 1:
# First Step in  backward elimination is select a significance level or Select P-value
#
# Usually in most cases 5% Significance level  is selected . That means  P-value will be 0.5 you can change this value depending on your project
#
#
# # Step 2:
#
# Second Step is <b> fit your machine learning models with all features selected </b>
#
# So if there are 50 features you include all of them  in your model  and fit model on your test datset . No changes here
#
#
#
# # Step 3:
#
# In Step 3,Identify feature or predictor  which has highest P-value
#
#
# # Step 4:
#
# This is Significant Step Here we take Decissions . In prevous Step3 : we identified feature  which has highest P-Value
#
# - if P-Value is greater than significance level - we selected and remove this feature from our dataset
# - if P-valie is less than Significance Level  we just jump to Step 6 which means that we are done
#
#
# # Step 5
# Once we find out feature  which has to be removd from our dataset  we will fir the model again  with new dataset After fitting a model with new dataset  we will jump back to step 3:
#
# This Process will continue untill we reach a point  in step 4 where  highest P-Value  from all remaining features  in datset is  less than significance level selected step 1:
#
#
# In our Example this means iterate  from step 3 to Step 5 and back till  highest P-Value  in dataset is less than 0.05
#
# Out of  50 asssumed features   we might filter out  good 10 features
#
#
# # Step 6:
# Once We reach Step 6 We are done  with Feature Selection process we have Sucessfully used Backward Elimination Method

# %%
import statsmodels.api as sm

# %%
X.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
# ...

# %%
X.shape
# Out:
# Out[266]: (1337, 8)

# %% [markdown]
# Before We begin with Backward Elimination  we need  to append '1'  at begining of our datset now Why is Important ?
#
# Equation of line is y = b +m1x1 ;m2x2 +m3x3 +m4x4
#
# When we make  a linear model with sklearn , the <b> bias term is seperately calculated
#
#
# - However to perform Backward elimination  we have to use linear model provided  by statsmodel library  - Which doesnot consider bias term
#
# - Hence by adding  a dummy feature with value as '1'  our equation comes out to be  like this :
#
#     y = b*X0 + m1x1 + m2x2 +m3x3 + m4x4 where x0 =1

# %%
# adding a column of ones  as integer datatype

# X1 = (1337,1)  + (1337,9)

# Constant that is X1

X1 = np.append(arr = np.ones((1337,1)).astype(int),values=X,axis=1)

# %%
X.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
# ...

# %%
X1.shape
# Out:
# Out[269]: (1337, 9)

# %%
X1
# Out:
# Out[270]: array([[ 1. , 19. , 27.9, ...,  0. ,  0. ,  1. ],
#        [ 1. , 18. , 33.8, ...,  0. ,  1. ,  0. ],
#        [ 1. , 28. , 33. , ...,  0. ,  1. ,  0. ],
#        ...,
#        [ 1. , 18. , 36.9, ...,  0. ,  1. ,  0. ],
#        [ 1. , 21. , 25.8, ...,  0. ,  0. ,  1. ],
#        [ 1. , 61. , 29.1, ...,  1. ,  0. ,  0. ]])

# %%
# choose significance level  usually 0.05% if p>0.05
# for highest values parameter remove that value

X_opt = X1[:,[0,1,2,3,4,5,6,7,8]]
X_opt.shape
# Out:
# Out[275]: (1337, 9)

# %%
X.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>male</th>
#       <th>yes</th>
#       <th>northwest</th>
#       <th>southeast</th>
#       <th>southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.8</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
# ...

# %%
X_opt
# Out:
# Out[277]: array([[ 1. , 19. , 27.9, ...,  0. ,  0. ,  1. ],
#        [ 1. , 18. , 33.8, ...,  0. ,  1. ,  0. ],
#        [ 1. , 28. , 33. , ...,  0. ,  1. ,  0. ],
#        ...,
#        [ 1. , 18. , 36.9, ...,  0. ,  1. ,  0. ],
#        [ 1. , 21. , 25.8, ...,  0. ,  0. ,  1. ],
#        [ 1. , 61. , 29.1, ...,  1. ,  0. ,  0. ]])

# %%
# Constant with 0th column
X_opt[:,0]
# Out:
# Out[278]: array([1., 1., 1., ..., 1., 1., 1.])

# %%
# 'age' 1st column

X_opt[:,1]
# Out:
# Out[280]: array([19., 18., 28., ..., 18., 21., 61.])

# %%
# 'bmi' 2nd column

X_opt[:,2]
# Out:
# Out[281]: array([27.9, 33.8, 33. , ..., 36.9, 25.8, 29.1])

# %%
# 'children' 3rd column

X_opt[:,3]
# Out:
# Out[282]: array([0., 1., 3., ..., 0., 0., 0.])

# %%
# 'male' 4th column

X_opt[:,4]
# Out:
# Out[283]: array([0., 1., 1., ..., 0., 0., 0.])

# %%
# 'yes' 5th column

X_opt[:,5]
# Out:
# Out[284]: array([1., 0., 0., ..., 0., 0., 1.])

# %%
# 'north west' 6th column

X_opt[:,6]
# Out:
# Out[285]: array([0., 0., 0., ..., 0., 0., 1.])

# %%
# 'north East' 7th column

X_opt[:,7]
# Out:
# Out[286]: array([0., 1., 1., ..., 1., 0., 0.])

# %%
# 'SouthWest' 8th column

X_opt[:,8]
# Out:
# Out[288]: array([1., 0., 0., ..., 0., 1., 0.])

# %% [markdown]
# # OLS stands for 'Ordinary Least Squares' which essentially  train an linear model

# %%
ols = sm.OLS(endog=y,exog=X_opt).fit()
ols.summary()
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>         <td>charges</td>     <th>  R-squared:         </th> <td>   0.751</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.749</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   500.0</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sun, 28 Aug 2022</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>22:16:30</td>     <th>  Log-Likelihood:    </th> <td> -13538.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1337</td>      <th>  AIC:               </th> <td>2.709e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1328</td>      <th>  BIC:               </th> <td>2.714e+04</td>
# </tr>
# <tr>
# ...

# %% [markdown]
# # Observation :
# From the Summary, We Observe  that highest P-Value is for 4th Feature (X4-Male) is 0.698 , which is way over Significance level  of 0.05 Hence we will remove  'male'
# Feature

# %% [markdown]
# ## Now Remove  the variable X4

# %%
# Remove 4th Column (X4=Male) from  x1 is its highest p-value  is 0.698
# Build OLS  with remaining features  and check most significance value 

X_opt1 = X1[:,[0,1,2,3,5,6,7,8]]
X_opt1.shape
# Out:
# Out[290]: (1337, 8)

# %%
ols = sm.OLS(endog=y,exog=X_opt1).fit()
ols.summary()
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>         <td>charges</td>     <th>  R-squared:         </th> <td>   0.751</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.749</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   571.8</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sun, 28 Aug 2022</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>22:18:32</td>     <th>  Log-Likelihood:    </th> <td> -13538.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1337</td>      <th>  AIC:               </th> <td>2.709e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1329</td>      <th>  BIC:               </th> <td>2.713e+04</td>
# </tr>
# <tr>
# ...

# %% [markdown]
# # from observation
#
# we observe highest p-value  is for 6th Feature  of X1or X5 of X_opt1(NorthWest) is 0.465 which is way over significance level  of 0.05 Hence we remove it

# %%
# Remove 6th column (male)  from x1 as it is highest p-value  is 0.465
# Build OLS with Remaining Features  and check most significance value 


reg_opt2 = X1[:,[0,1,2,3,5,7,8]]
reg_opt2.shape
# Out:
# Out[292]: (1337, 7)

# %%
ols = sm.OLS(endog=y,exog=reg_opt2).fit()
ols.summary()
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>         <td>charges</td>     <th>  R-squared:         </th> <td>   0.751</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.750</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   667.3</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sun, 28 Aug 2022</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>22:19:38</td>     <th>  Log-Likelihood:    </th> <td> -13538.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1337</td>      <th>  AIC:               </th> <td>2.709e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1330</td>      <th>  BIC:               </th> <td>2.713e+04</td>
# </tr>
# <tr>
# ...

# %%
# from observation 

# we observe highest p-value  is for 8th Feature  of X1or X6 of X_opt2(Southwest) is 0.058 which is way over significance level  of 0.05 Hence we remove it


X_opt3 = X1[:,[0,1,2,3,5,7]]
X_opt3.shape
# Out:
# Out[294]: (1337, 6)

# %%
ols = sm.OLS(endog=y,exog=X_opt3).fit()
ols.summary()
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>         <td>charges</td>     <th>  R-squared:         </th> <td>   0.750</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.749</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   798.4</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sun, 28 Aug 2022</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>22:20:18</td>     <th>  Log-Likelihood:    </th> <td> -13540.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1337</td>      <th>  AIC:               </th> <td>2.709e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1331</td>      <th>  BIC:               </th> <td>2.712e+04</td>
# </tr>
# <tr>
# ...

# %%
# from observation 

# we observe highest p-value  is for 7th Feature  of X1or X5 of X_opt3(SouthEast) is 0.138 which is way over significance level  of 0.05 Hence we remove it
X_opt4 = X1[:,[0,1,2,3,5]]
X_opt4.shape
# Out:
# Out[298]: (1337, 5)

# %%
ols = sm.OLS(endog=y,exog=X_opt4).fit()
ols.summary()
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>         <td>charges</td>     <th>  R-squared:         </th> <td>   0.750</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th>  Adj. R-squared:    </th> <td>   0.749</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   996.6</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sun, 28 Aug 2022</td> <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>22:21:38</td>     <th>  Log-Likelihood:    </th> <td> -13541.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1337</td>      <th>  AIC:               </th> <td>2.709e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1332</td>      <th>  BIC:               </th> <td>2.712e+04</td>
# </tr>
# <tr>
# ...

# %%
X_opt4
# Out:
# Out[300]: array([[ 1. , 19. , 27.9,  0. ,  1. ],
#        [ 1. , 18. , 33.8,  1. ,  0. ],
#        [ 1. , 28. , 33. ,  3. ,  0. ],
#        ...,
#        [ 1. , 18. , 36.9,  0. ,  0. ],
#        [ 1. , 21. , 25.8,  0. ,  0. ],
#        [ 1. , 61. , 29.1,  0. ,  1. ]])

# %%
X_train,X_test,y_train,y_test = train_test_split(X_opt4,y,test_size=0.2,random_state=0)
new_model = LinearRegression()
new_model.fit(X_train,y_train)
# Out:
# Out[301]: LinearRegression()

# %%
new_pred = new_model.predict(X_test)

# %%
# train Score After applying Backward Elimination Method
train1_score = new_model.score(X_train,y_train)
print("Train_score",train1_score)
# Out:
# Train_score 0.7475161330538833

# %%
score = r2_score(y_test,new_pred)
print("r_2_score",score)
# Out:
# r_2_score 0.7525425247622064

# %%
#  BEfore Backward Elimination  r_2 score : 0.74
# After Apllying  Backward Elimination : 0.75


print("Mean Absolute  Error",metrics.mean_absolute_error(y_test,new_pred))
print("Mean Squared Error",metrics.mean_squared_error(y_test,new_pred))
print("Root Mean Square Error",np.sqrt(metrics.mean_absolute_error(y_test,new_pred)))
# Out:
# Mean Absolute  Error 4391.290382885985
# Mean Squared Error 41629663.85917102
# Root Mean Square Error 66.26681207728335

# %%
new_df = pd.DataFrame({'Actual':y_test,'predicted':new_pred,'variance':y_test-new_pred})
new_df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Actual</th>
#       <th>predicted</th>
#       <th>variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1248</th>
#       <td>1633.96</td>
#       <td>5217.560992</td>
#       <td>-3583.600992</td>
#     </tr>
#     <tr>
#       <th>610</th>
#       <td>8547.69</td>
#       <td>9722.472057</td>
#       <td>-1174.782057</td>
#     </tr>
#     <tr>
#       <th>393</th>
#       <td>9290.14</td>
#       <td>10807.157449</td>
#       <td>-1517.017449</td>
#     </tr>
#     <tr>
#       <th>503</th>
#       <td>32548.34</td>
#       <td>26408.035356</td>
#       <td>6140.304644</td>
#     </tr>
# ...

# %%
X_opt4[198,:]
# Out:
# Out[307]: array([ 1. , 51. , 18.1,  0. ,  0. ])

# %%
new_model.predict([[1. , 51. , 18.1,  0. ,  0.]])
# Out:
# Out[308]: array([6858.50854979])

# %%
print("intercept",new_model.intercept_)
# Out:
# intercept -11023.376797378667

# %%
print("Coefficients",new_model.coef_)
# Out:
# Coefficients [    0.           245.15144532   297.1912506    486.30815668
#  23768.63979903]

# %%
0*1+245.15144532*51 +   297.1912506*18.1 +   486.30815668*0+ 23768.63979903*0 -11023.376797378616
# Out:
# Out[311]: 6858.508549801383
